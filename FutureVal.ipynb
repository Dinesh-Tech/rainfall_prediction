# %% [markdown]
# # Imports

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Read Input
#
# The input file is present as inp.csv

# %%
df = pd.read_csv('inp.csv')
df = df.dropna(how='all')
df.index = df['YEAR']
df = df.drop('YEAR', axis=1)
df
# Out:
#           JAN    FEB    MAR    APR    MAY    JUN    JUL    AUG    SEP    OCT  \
# YEAR
# 1901.0   49.2   87.1   29.2    2.3  528.8  517.5  365.1  481.1  332.6  388.5
# 1902.0    0.0  159.8   12.2    0.0  446.1  537.1  228.9  753.7  666.2  197.2
# 1903.0   12.7  144.0    0.0    1.0  235.1  479.9  728.4  326.7  339.0  181.2
# 1904.0    9.4   14.7    0.0  202.4  304.5  495.1  502.0  160.1  820.4  222.2
# 1905.0    1.3    0.0    3.3   26.9  279.5  628.7  368.7  330.5  297.0  260.7
# ...       ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 2011.0  265.9   84.8  272.8  111.4  326.5  383.2  583.2  441.5  757.1  212.3
# 2012.0  119.9   45.6   30.9   55.8  533.9  458.2  317.3  369.6  868.9  209.7
# 2013.0   67.1   37.6   43.0   46.3  509.3  777.0  564.8  336.7  473.6  455.8
# 2014.0   41.9    8.6    0.0   11.1  238.0  416.6  467.6  321.6  412.9  402.6
# 2015.0  126.8    7.6    3.1  138.2  331.9  346.4  328.9  480.0  523.3  252.1
#
#           NOV    DEC
# YEAR
# ...

# %% [markdown]
# # Fill empty rows for years that are absent

# %%
min_year = int(min(df.index))
max_year = int(max(df.index))
print(min_year, max_year)
df_all_years = df.reindex(list(range(min_year, max_year+1+2)))
df
# Out:
# 1901 2015
#           JAN    FEB    MAR    APR    MAY    JUN    JUL    AUG    SEP    OCT  \
# YEAR
# 1901.0   49.2   87.1   29.2    2.3  528.8  517.5  365.1  481.1  332.6  388.5
# 1902.0    0.0  159.8   12.2    0.0  446.1  537.1  228.9  753.7  666.2  197.2
# 1903.0   12.7  144.0    0.0    1.0  235.1  479.9  728.4  326.7  339.0  181.2
# 1904.0    9.4   14.7    0.0  202.4  304.5  495.1  502.0  160.1  820.4  222.2
# 1905.0    1.3    0.0    3.3   26.9  279.5  628.7  368.7  330.5  297.0  260.7
# ...       ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 2011.0  265.9   84.8  272.8  111.4  326.5  383.2  583.2  441.5  757.1  212.3
# 2012.0  119.9   45.6   30.9   55.8  533.9  458.2  317.3  369.6  868.9  209.7
# 2013.0   67.1   37.6   43.0   46.3  509.3  777.0  564.8  336.7  473.6  455.8
# 2014.0   41.9    8.6    0.0   11.1  238.0  416.6  467.6  321.6  412.9  402.6
# 2015.0  126.8    7.6    3.1  138.2  331.9  346.4  328.9  480.0  523.3  252.1
#
#           NOV    DEC
# ...

# %% [markdown]
# # Compute future Values

# %%
futurevals = df_all_years.copy()
futurevals.index = list(range(min_year-2, max_year+1))
futurevals = futurevals.loc[min_year:max_year-2,:]
futurevals
# Out:
#         JAN    FEB    MAR    APR    MAY    JUN    JUL    AUG    SEP    OCT  \
# 1901   12.7  144.0    0.0    1.0  235.1  479.9  728.4  326.7  339.0  181.2
# 1902    9.4   14.7    0.0  202.4  304.5  495.1  502.0  160.1  820.4  222.2
# 1903    1.3    0.0    3.3   26.9  279.5  628.7  368.7  330.5  297.0  260.7
# 1904   36.6    0.0    0.0    0.0  556.1  733.3  247.7  320.5  164.3  267.8
# 1905  110.7    0.0  113.3   21.6  616.3  305.2  443.9  377.6  200.4  264.4
# ...     ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 2009  265.9   84.8  272.8  111.4  326.5  383.2  583.2  441.5  757.1  212.3
# 2010  119.9   45.6   30.9   55.8  533.9  458.2  317.3  369.6  868.9  209.7
# 2011   67.1   37.6   43.0   46.3  509.3  777.0  564.8  336.7  473.6  455.8
# 2012   41.9    8.6    0.0   11.1  238.0  416.6  467.6  321.6  412.9  402.6
# 2013  126.8    7.6    3.1  138.2  331.9  346.4  328.9  480.0  523.3  252.1
#
#         NOV    DEC
# 1901  284.4  225.0
# 1902  308.7   40.1
# ...

# %% [markdown]
# # Add prefix to values in futurevals

# %%
for month in futurevals.columns:
    for year in futurevals.index:
        futurevals.loc[year, month] = f"{year+2}-{month}-{futurevals.loc[year, month]}"

# %%
futurevals
# Out:
#                  JAN                         FEB             MAR  \
# 1901   1903-JAN-12.7              1903-FEB-144.0    1903-MAR-0.0
# 1902    1904-JAN-9.4               1904-FEB-14.7    1904-MAR-0.0
# 1903    1905-JAN-1.3                1905-FEB-0.0    1905-MAR-3.3
# 1904   1906-JAN-36.6                1906-FEB-0.0    1906-MAR-0.0
# 1905  1907-JAN-110.7                1907-FEB-0.0  1907-MAR-113.3
# ...              ...                         ...             ...
# 2009  2011-JAN-265.9  2011-FEB-84.79999999999998  2011-MAR-272.8
# 2010  2012-JAN-119.9               2012-FEB-45.6   2012-MAR-30.9
# 2011   2013-JAN-67.1               2013-FEB-37.6   2013-MAR-43.0
# 2012   2014-JAN-41.9  2014-FEB-8.599999999999998    2014-MAR-0.0
# 2013  2015-JAN-126.8  2015-FEB-7.599999999999999    2015-MAR-3.1
#
#                  APR             MAY                         JUN  \
# 1901    1903-APR-1.0  1903-MAY-235.1              1903-JUN-479.9
# ...

# %% [markdown]
# # Write output 'out.csv' to disk
